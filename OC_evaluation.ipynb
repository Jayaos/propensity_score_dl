# %%
from src.utils import *
import matplotlib.pyplot as plt
from src.PSMLP import *
from src.PSLSTM import *
from src.PSLR import *
from src.PSCodeBERT import *
from src.PSVisitBERT import *

# %%
load_

# %%
PSLR_evaluation_dict = nfold_evaluate_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                     "occurrence_count_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSLR/", 10, 
                     100, [0.05,0.95], [0.05,0.95], HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 907.20it/s]
# IPW-ATE : -2.656734499136607
# PS-MAE : 0.04623684659600258
# weighted PS-MAE : 0.024503642693161964
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 803.78it/s]
# IPW-ATE with trimming: -2.656734433968862
# PS-MAE with trimming: 0.04623685032129288
# evaluation starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1213.72it/s]
# IPW-ATE with clip: -2.6567348424593606
# PS-MAE with clip: 0.04623684659600258
# evaluation starts...
# ...

# %%
PSLR_HDPS_evaluation_dict = nfold_evaluate_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                     "occurrence_count_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSLR_HDPS/", 10, 
                     100, [0.05,0.95], [0.05,0.95], HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:02<00:00, 468.68it/s]
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 910.45it/s]
# IPW-ATE : 3.527617733478546
# PS-MAE : 0.09796347469091415
# weighted PS-MAE : 0.05649256333708763
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 730.77it/s]
# IPW-ATE with trimming: 3.527617632548014
# PS-MAE with trimming: 0.09796348214149475
# evaluation starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1071.00it/s]
# ...

# %%
PSMLP_evaluation_dict = nfold_evaluate_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                     "occurrence_count_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSMLP/", 10, 
                     64, 64, 101, 2, [0.05,0.95], [0.05,0.95], HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 381.04it/s]
# evaluation done...
# IPW-ATE : -3.4706371720631917
# PS-MAE : 0.06698347628116608
# weighted PS-MAE : 0.03654396906495094
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 399.37it/s]
# evaluation done...
# IPW-ATE with trimming: -3.145823996861776
# PS-MAE with trimming: 0.06721856445074081
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 434.32it/s]
# evaluation done...
# IPW-ATE with clip: -3.4473644924163818
# PS-MAE with clip: 0.0659785121679306
# ...

# %%
PSMLP_HDPS_evaluation_dict = nfold_evaluate_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                     "occurrence_count_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSMLP_HDPS/", 10, 
                     64, 64, 101, 2, [0.05,0.95], [0.05,0.95], HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:03<00:00, 397.38it/s]
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 363.42it/s]
# evaluation done...
# IPW-ATE : 0.5176644277572632
# PS-MAE : 0.10610150545835495
# weighted PS-MAE : 0.055623676627874374
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 300.92it/s]
# evaluation done...
# IPW-ATE with trimming: 0.5369939629236857
# PS-MAE with trimming: 0.10665464401245117
# evaluation starts...
# ...

# %%
PSLSTM_evaluation_dict = nfold_evaluate_PSLSTM("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                     "occurrence_count_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSLSTM/",
                      10, 64, 64, 104, 2, [0.05,0.95], [0.05,0.95])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:01<00:00, 65.68it/s]
# evaluation done...
# IPW-ATE : -5.084795864423116
# PS-MAE : 0.06711158156394958
# weighted PS-MAE : 0.028371959924697876
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:01<00:00, 60.24it/s]
# evaluation done...
# IPW-ATE with trimming: -4.8657850075883475
# PS-MAE with trimming: 0.06713268905878067
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:01<00:00, 60.68it/s]
# evaluation done...
# IPW-ATE with clip: -5.093321978251139
# PS-MAE with clip: 0.06824945658445358
# ...

# %%
PSVisitBERT_evaluation_dict = nfold_evaluate_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                     "occurrence_count_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSVisitBERT/", 
                               10, 64, 64, 104, 2, 4, 
                          [1,2,3], [0.05,0.95], [0.05,0.95])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:04<00:00, 29.03it/s]
# evaluation done...
# IPW-ATE : -5.028990691502889
# PS-MAE : 0.08941919356584549
# weighted PS-MAE : 0.040425240993499756
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:03<00:00, 32.91it/s]
# evaluation done...
# IPW-ATE with trimming: -5.024402077542035
# PS-MAE with trimming: 0.08946017175912857
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:03<00:00, 31.70it/s]
# evaluation done...
# IPW-ATE with clip: -5.029032589594523
# PS-MAE with clip: 0.08941542357206345
# ...

# %%
PSCodeBERT_evaluation_dict = nfold_evaluate_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                     "occurrence_count_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSCodeBERT/", 
                               10, 64, 64, 104, 2, 4, 
                          [1,2,3], [0.05,0.95], [0.05,0.95])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:05<00:00, 22.30it/s]
# evaluation done...
# IPW-ATE : -11.355636049906412
# PS-MAE : 0.0767083689570427
# weighted PS-MAE : 0.03227110952138901
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:05<00:00, 22.42it/s]
# evaluation done...
# IPW-ATE with trimming: -11.355636189778647
# PS-MAE with trimming: 0.0767083540558815
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:05<00:00, 22.49it/s]
# evaluation done...
# IPW-ATE with clip: -11.355636049906412
# PS-MAE with clip: 0.0767083466053009
# ...

# %%
summarize_evaluation_dict(PSLR_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.044952671974897385
# PS_MAE 95% CI: (0.04367916320635215, 0.04622618074344262)
# PS_MAE CI half width: -0.001273508768545234
# weighted PS_MAE mean: 0.023127116076648236
# weighted PS_MAE 95% CI: (0.02220744964919942, 0.02404678250409705)
# weighted PS_MAE CI half width: -0.0009196664274488155
# ----------------------
# MAE_IPW_ATE: 3.0827794075012207
# IPW_ATE 95% CI: (-7.508345664198153, -2.541698921506651)
# IPW_ATE CI half width: -2.483323371345751
# ----------------------
# trimming MAE_IPW_ATE: 3.00920033454895
# trimming IPW_ATE 95% CI: (-7.394329899324535, -2.5415658736131634)
# trimming IPW_ATE CI half width: -2.4263820128556857
# ----------------------
# clip MAE_IPW_ATE: 3.0813586711883545
# clip IPW_ATE 95% CI: (-7.505562397186484, -2.5414432738378383)
# clip IPW_ATE CI half width: -2.4820595616743226

# %%
summarize_evaluation_dict(PSLR_HDPS_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.10054755881428719
# PS_MAE 95% CI: (0.09880528128802715, 0.10228983634054722)
# PS_MAE CI half width: -0.001742277526260036
# weighted PS_MAE mean: 0.0551319882273674
# weighted PS_MAE 95% CI: (0.05229999781601857, 0.05796397863871623)
# weighted PS_MAE CI half width: -0.0028319904113488295
# ----------------------
# MAE_IPW_ATE: 5.226099967956543
# IPW_ATE 95% CI: (-5.046568307066085, 2.554173427407069)
# IPW_ATE CI half width: -3.800370867236577
# ----------------------
# trimming MAE_IPW_ATE: 5.240029335021973
# trimming IPW_ATE 95% CI: (-5.077983692154022, 2.542742395138462)
# trimming IPW_ATE CI half width: -3.810363043646242
# ----------------------
# clip MAE_IPW_ATE: 5.226071357727051
# clip IPW_ATE 95% CI: (-5.046493658516949, 2.554206079934185)
# clip IPW_ATE CI half width: -3.8003498692255673

# %%
summarize_evaluation_dict(PSMLP_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.07064224854111671
# PS_MAE 95% CI: (0.0684327659336148, 0.07285173114861862)
# PS_MAE CI half width: -0.0022094826075019086
# weighted PS_MAE mean: 0.03678178824484348
# weighted PS_MAE 95% CI: (0.03583332845466122, 0.03773024803502574)
# weighted PS_MAE CI half width: -0.0009484597901822586
# ----------------------
# MAE_IPW_ATE: 4.218192100524902
# IPW_ATE 95% CI: (-11.49802026714488, -6.326618130071915)
# IPW_ATE CI half width: -2.5857010685364834
# ----------------------
# trimming MAE_IPW_ATE: 4.208357810974121
# trimming IPW_ATE 95% CI: (-11.525539930205792, -6.149506376904534)
# trimming IPW_ATE CI half width: -2.6880167766506293
# ----------------------
# clip MAE_IPW_ATE: 4.329651832580566
# clip IPW_ATE 95% CI: (-11.515138976397996, -6.0743195842277125)
# clip IPW_ATE CI half width: -2.7204096960851416

# %%
summarize_evaluation_dict(PSMLP_HDPS_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.10642563179135323
# PS_MAE 95% CI: (0.10269585288960476, 0.1101554106931017)
# PS_MAE CI half width: -0.0037297789017484706
# weighted PS_MAE mean: 0.05477045588195324
# weighted PS_MAE 95% CI: (0.052819100460557974, 0.05672181130334851)
# weighted PS_MAE CI half width: -0.0019513554213952677
# ----------------------
# MAE_IPW_ATE: 3.721759080886841
# IPW_ATE 95% CI: (-7.654817626024522, -1.443184202010198)
# IPW_ATE CI half width: -3.1058167120071625
# ----------------------
# trimming MAE_IPW_ATE: 3.7957935333251953
# trimming IPW_ATE 95% CI: (-7.49358670007163, -1.2918919708433392)
# trimming IPW_ATE CI half width: -3.100847364614145
# ----------------------
# clip MAE_IPW_ATE: 3.893620252609253
# clip IPW_ATE 95% CI: (-7.868187191816913, -1.4515350632540915)
# clip IPW_ATE CI half width: -3.208326064281411

# %%
summarize_evaluation_dict(PSLSTM_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.06927429549396039
# PS_MAE 95% CI: (0.0652301771377813, 0.07331841385013947)
# PS_MAE CI half width: -0.0040441183561790855
# weighted PS_MAE mean: 0.028337972052395344
# weighted PS_MAE 95% CI: (0.02660462502897814, 0.03007131907581255)
# weighted PS_MAE CI half width: -0.0017333470234172053
# ----------------------
# MAE_IPW_ATE: 1.7441949844360352
# IPW_ATE 95% CI: (-5.997344384197065, -2.8918952970468315)
# IPW_ATE CI half width: -1.552724543575117
# ----------------------
# trimming MAE_IPW_ATE: 1.7825664281845093
# trimming IPW_ATE 95% CI: (-5.9808400948297855, -2.8475424679669437)
# trimming IPW_ATE CI half width: -1.5666488134314207
# ----------------------
# clip MAE_IPW_ATE: 1.747897744178772
# clip IPW_ATE 95% CI: (-5.947394056168966, -2.848281660866964)
# clip IPW_ATE CI half width: -1.5495561976510013

# %%
summarize_evaluation_dict(PSVisitBERT_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.0919829361140728
# PS_MAE 95% CI: (0.08800639162660426, 0.09595948060154133)
# PS_MAE CI half width: -0.003976544487468536
# weighted PS_MAE mean: 0.040757711976766586
# weighted PS_MAE 95% CI: (0.038825508042827445, 0.04268991591070573)
# weighted PS_MAE CI half width: -0.0019322039339391417
# ----------------------
# MAE_IPW_ATE: 1.06272292137146
# IPW_ATE 95% CI: (-5.063242205028679, -3.3402840880901175)
# IPW_ATE CI half width: -0.8614790584692811
# ----------------------
# trimming MAE_IPW_ATE: 1.0676158666610718
# trimming IPW_ATE 95% CI: (-5.0663499713867655, -3.3221395751785345)
# trimming IPW_ATE CI half width: -0.8721051981041157
# ----------------------
# clip MAE_IPW_ATE: 1.0570825338363647
# clip IPW_ATE 95% CI: (-5.068667464622248, -3.346163083664191)
# clip IPW_ATE CI half width: -0.8612521904790285

# %%
summarize_evaluation_dict(PSCodeBERT_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.070383071154356
# PS_MAE 95% CI: (0.0663843554523012, 0.07438178685641081)
# PS_MAE CI half width: -0.003998715702054803
# weighted PS_MAE mean: 0.030227498337626457
# weighted PS_MAE 95% CI: (0.028749301364041125, 0.031705695311211785)
# weighted PS_MAE CI half width: -0.0014781969735853315
# ----------------------
# MAE_IPW_ATE: 4.236247539520264
# IPW_ATE 95% CI: (-10.43293366588029, -8.03956262607502)
# IPW_ATE CI half width: -1.1966855199026352
# ----------------------
# trimming MAE_IPW_ATE: 4.23624849319458
# trimming IPW_ATE 95% CI: (-10.432933744006267, -8.03956272263039)
# trimming IPW_ATE CI half width: -1.1966855106879386
# ----------------------
# clip MAE_IPW_ATE: 4.236247539520264
# clip IPW_ATE 95% CI: (-10.432933623935261, -8.039562684073564)
# clip IPW_ATE CI half width: -1.1966854699308485

# %%
nfold_plot_propensity_score_LR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                     "occurrence_count_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSLR/", 
                               10, 100, HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1917.10it/s]

# %%
nfold_plot_propensity_score_MLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                     "occurrence_count_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSMLP/", 
                               10, 64, 64, 101, 2, HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 418.97it/s]

# %%
nfold_plot_propensity_score_PSLSTM("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                     "occurrence_count_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSLSTM/",
                                   10, 64, 64, 104, 2)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:02<00:00, 44.22it/s]

# %%
nfold_plot_propensity_score_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                     "occurrence_count_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSVisitBERT/",
                                   10, 64, 64, 104, 2, 4, [1,2,3])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:03<00:00, 32.85it/s]

# %%
nfold_plot_propensity_score_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                     "occurrence_count_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSCodeBERT/", 
                                       10, 64, 64, 104, 2, 4, [1,2,3], masking_prob=None)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:05<00:00, 22.54it/s]
