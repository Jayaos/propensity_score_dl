# %%
from src.PSVisitBERT import *
from src.PSCodeBERT import *
from src.SyntheticDataGeneration import *
from src.utils import *
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
nfold_average_attention_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/", 
                                   "synthea_sinusitis_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/synthea_sinusitis_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea/PSVisitBERT/", 
                                   5, 64, 64, 131, 2, 4, [1,2,3])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 137/137 [00:02<00:00, 48.60it/s]
# target_attention_weight_avg: 0.21475667580962182
# target_attention_weight 95% CI: (0.15568602358234107, 0.2738273280369026)
# target_attention_weight CI half width: -0.05907065222728075
# ----------------------
# rest_attention_weight_avg: 0.11441905200481414
# rest_attention_weight 95% CI: (0.08402027698572588, 0.1448178270239024)
# rest_attention_weight CI half width: -0.03039877501908826
# ----------------------
# CLS_attention_weight_avg: 0.1226673349738121
# CLS_attention_weight 95% CI: (0.08594247455869228, 0.15939219538893193)
# CLS_attention_weight CI half width: -0.036724860415119825

# %%
nfold_average_attention_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/", 
                                   "synthea_sinusitis_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/synthea_sinusitis_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea/PSCodeBERT/", 
                                   5, 64, 64, 131, 2, 4, [1,2,3])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 137/137 [00:02<00:00, 55.68it/s]
# target_attention_weight_avg: 0.18620679378509522
# target_attention_weight 95% CI: (0.15234834509048933, 0.2200652424797011)
# target_attention_weight CI half width: -0.033858448694605886
# ----------------------
# rest_attention_weight_avg: 0.09070226848125458
# rest_attention_weight 95% CI: (0.07462943820258278, 0.10677509875992638)
# rest_attention_weight CI half width: -0.016072830278671804
# ----------------------
# CLS_attention_weight_avg: 0.20760631561279297
# CLS_attention_weight 95% CI: (0.18212583226384174, 0.2330867989617442)
# CLS_attention_weight CI half width: -0.025480483348951227

# %%
pd = load_data("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/synthea_sinusitis_params.pkl")

# %%
pd
# Out:
# {'treatment_effect': -5,
#  'alpha': 5,
#  'bias': 10,
#  'ps_noise_var': 0.01,
#  'outcome_noise_var': 0.1,
#  'num_token_reserve': 4,
#  'temporal_confounding_var': 30,
#  'fixed_confounding_var': 116}

# %%
pd["confounding_var"] = np.array([pd["temporal_confounding_var"], pd["fixed_confounding_var"]])

# %%
save_data("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/synthea_sinusitis_params.pkl", pd)

# %%
a,b,c,d,e = plot_attention_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/", 
                                   "synthea_sinusitis_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/synthea_sinusitis_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea/PSVisitBERT/", 
                                   5, 64, 64, 131, 2, 4, 10, 1, [1,2,3],
                                  "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/figures/attention_map/")
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data

# %%
a,b,c = plot_attention_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/", 
                                   "synthea_sinusitis_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/synthea_sinusitis_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea/PSCodeBERT/", 
                                   5, 64, 64, 131, 2, 4, 10, 1, [1,2,3], None,
                                  "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/figures/attention_map/Synthea/")
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
