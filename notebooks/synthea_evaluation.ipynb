# %%
from src.utils import *
import matplotlib.pyplot as plt
from src.PSMLP import *
from src.PSLSTM import *
from src.PSLR import *
from src.PSCodeBERT import *
from src.PSVisitBERT import *

# %%
PSLR_evaluation_dict = nfold_evaluate_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/", 
                     "synthea_sinusitis_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea/PSLR/", 5, 
                     127, [0.05,0.95], [0.05,0.95], HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 837.74it/s]
# IPW-ATE : -2.2778102129915334
# PS-MAE : 0.17506198585033417
# weighted PS-MAE : 0.0991271436214447
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 730.95it/s]
# IPW-ATE with trimming: -2.963105133851486
# PS-MAE with trimming: 0.1739160716533661
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 903.17it/s]
# IPW-ATE with clip: -2.7925034418593357
# PS-MAE with clip: 0.17518401145935059
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 940.37it/s]
# IPW-ATE : -3.984827503844769
# ...

# %%
PSLR_HDPS_evaluation_dict = nfold_evaluate_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/", 
                     "synthea_sinusitis_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea/PSLR_HDPS/", 5, 
                     127, [0.05,0.95], [0.05,0.95], HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# 100%|█████████████████████████████████████████████████████████████████████████████| 1372/1372 [00:02<00:00, 500.45it/s]
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 578.69it/s]
# IPW-ATE : -2.564908338115163
# PS-MAE : 0.17105558514595032
# weighted PS-MAE : 0.10002467781305313
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 492.60it/s]
# IPW-ATE with trimming: -2.570840275896727
# PS-MAE with trimming: 0.17080891132354736
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 715.71it/s]
# IPW-ATE with clip: -2.5734079124283618
# PS-MAE with clip: 0.1709219068288803
# ...

# %%
PSMLP_evaluation_dict = nfold_evaluate_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/", 
                     "synthea_sinusitis_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea/PSMLP/", 5, 
                     64, 64, 128, 2, [0.05,0.95], [0.05,0.95], HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 618.23it/s]
# evaluation done...
# IPW-ATE : -2.8809061934478093
# PS-MAE : 0.1736140251159668
# weighted PS-MAE : 0.09889396280050278
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 509.68it/s]
# evaluation done...
# IPW-ATE with trimming: -2.879493762106791
# PS-MAE with trimming: 0.1734578013420105
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 711.54it/s]
# evaluation done...
# IPW-ATE with clip: -2.871791881366368
# PS-MAE with clip: 0.17354217171669006
# evaluation starts...
# ...

# %%
PSMLP_HDPS_evaluation_dict = nfold_evaluate_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/", 
                     "synthea_sinusitis_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea/PSMLP_HDPS/", 5, 
                     64, 64, 128, 2, [0.05,0.95], [0.05,0.95], HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# 100%|████████████████████████████████████████████████████████████████████████████| 1372/1372 [00:00<00:00, 4950.98it/s]
# evaluation starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 3603.29it/s]
# evaluation done...
# IPW-ATE : -3.4518159567004574
# PS-MAE : 0.1746620386838913
# weighted PS-MAE : 0.09756332635879517
# evaluation starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 2686.32it/s]
# evaluation done...
# IPW-ATE with trimming: -3.5899251193025687
# PS-MAE with trimming: 0.1746927797794342
# evaluation starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 137/137 [00:00<00:00, 3656.41it/s]
# evaluation done...
# IPW-ATE with clip: -3.595215388806197
# PS-MAE with clip: 0.17368865013122559
# ...

# %%
PSLSTM_evaluation_dict = nfold_evaluate_PSLSTM("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/", 
                     "synthea_sinusitis_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea/PSLSTM/",
                      5, 64, 64, 131, 2, [0.05,0.95], [0.05,0.95])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 137/137 [00:01<00:00, 88.54it/s]
# evaluation done...
# IPW-ATE : -3.5729667607885207
# PS-MAE : 0.12596732378005981
# weighted PS-MAE : 0.07322393357753754
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 137/137 [00:01<00:00, 86.86it/s]
# evaluation done...
# IPW-ATE with trimming: -3.633254872621411
# PS-MAE with trimming: 0.1263570338487625
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 137/137 [00:01<00:00, 92.87it/s]
# evaluation done...
# IPW-ATE with clip: -3.4766165559309243
# PS-MAE with clip: 0.12392369657754898
# evaluation starts...
# ...

# %%
PSVisitBERT_evaluation_dict = nfold_evaluate_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/", 
                     "synthea_sinusitis_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea/PSVisitBERT/", 
                               5, 64, 64, 131, 2, 4, 
                          [1,2,3], [0.05,0.95], [0.05,0.95])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 137/137 [00:03<00:00, 44.86it/s]
# evaluation done...
# IPW-ATE : -5.195770205198413
# PS-MAE : 0.1552484929561615
# weighted PS-MAE : 0.08393301069736481
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 137/137 [00:02<00:00, 47.28it/s]
# evaluation done...
# IPW-ATE with trimming: -5.201744494472977
# PS-MAE with trimming: 0.15472668409347534
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 137/137 [00:02<00:00, 51.62it/s]
# evaluation done...
# IPW-ATE with clip: -5.176475061291326
# PS-MAE with clip: 0.1547686904668808
# evaluation starts...
# ...

# %%
PSCodeBERT_evaluation_dict = nfold_evaluate_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea/", 
                     "synthea_sinusitis_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea/PSCodeBERT/", 
                               5, 64, 64, 131, 2, 4, 
                          [1,2,3], [0.05,0.95], [0.05,0.95])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 137/137 [00:03<00:00, 43.87it/s]
# evaluation done...
# IPW-ATE : -3.785551451940606
# PS-MAE : 0.17366234958171844
# weighted PS-MAE : 0.09489670395851135
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 137/137 [00:03<00:00, 44.77it/s]
# evaluation done...
# IPW-ATE with trimming: -3.780877181561324
# PS-MAE with trimming: 0.17395105957984924
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 137/137 [00:03<00:00, 41.85it/s]
# evaluation done...
# IPW-ATE with clip: -3.763324726411026
# PS-MAE with clip: 0.17384780943393707
# evaluation starts...
# ...

# %%
summarize_evaluation_dict(PSLR_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.17238122820854188
# PS_MAE 95% CI: (0.16950211601723356, 0.1752603403998502)
# PS_MAE CI half width: -0.0028791121913083195
# weighted PS_MAE mean: 0.09417828619480133
# weighted PS_MAE 95% CI: (0.08993469938974313, 0.09842187299985952)
# weighted PS_MAE CI half width: -0.004243586805058194
# ----------------------
# MAE_IPW_ATE: 1.2687067985534668
# IPW_ATE 95% CI: (-5.271223572015233, -2.1913629692650263)
# IPW_ATE CI half width: -1.5399303013751036
# ----------------------
# trimming MAE_IPW_ATE: 1.0937325954437256
# trimming IPW_ATE 95% CI: (-4.691867379927397, -3.120667508744072)
# trimming IPW_ATE CI half width: -0.7855999355916627
# ----------------------
# clip MAE_IPW_ATE: 1.0879842042922974
# clip IPW_ATE 95% CI: (-4.899579050545477, -2.9244527753902756)
# clip IPW_ATE CI half width: -0.9875631375776006

# %%
summarize_evaluation_dict(PSLR_HDPS_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.169945627450943
# PS_MAE 95% CI: (0.16776786652578338, 0.1721233883761026)
# PS_MAE CI half width: -0.0021777609251596164
# weighted PS_MAE mean: 0.09411763846874237
# weighted PS_MAE 95% CI: (0.08953875196586031, 0.09869652497162443)
# weighted PS_MAE CI half width: -0.00457888650288206
# ----------------------
# MAE_IPW_ATE: 1.1700745820999146
# IPW_ATE 95% CI: (-4.819147604398457, -2.8407033974245786)
# IPW_ATE CI half width: -0.9892221034869388
# ----------------------
# trimming MAE_IPW_ATE: 1.158382773399353
# trimming IPW_ATE 95% CI: (-4.819181270081975, -2.8640531404476137)
# trimming IPW_ATE CI half width: -0.9775640648171806
# ----------------------
# clip MAE_IPW_ATE: 1.1837583780288696
# clip IPW_ATE 95% CI: (-4.781866843335749, -2.850616304612579)
# clip IPW_ATE CI half width: -0.9656252693615848

# %%
summarize_evaluation_dict(PSMLP_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.17062868475914
# PS_MAE 95% CI: (0.168432562215849, 0.172824807302431)
# PS_MAE CI half width: -0.0021961225432909903
# weighted PS_MAE mean: 0.09388232529163361
# weighted PS_MAE 95% CI: (0.08981391437321923, 0.09795073621004799)
# weighted PS_MAE CI half width: -0.004068410918414381
# ----------------------
# MAE_IPW_ATE: 1.2577117681503296
# IPW_ATE 95% CI: (-4.41352654702989, -3.071049907132707)
# IPW_ATE CI half width: -0.6712383199485914
# ----------------------
# trimming MAE_IPW_ATE: 1.2741632461547852
# trimming IPW_ATE 95% CI: (-4.41309879584165, -3.03857466618379)
# trimming IPW_ATE CI half width: -0.6872620648289303
# ----------------------
# clip MAE_IPW_ATE: 1.2569220066070557
# clip IPW_ATE 95% CI: (-4.445462321529062, -3.040693675698517)
# clip IPW_ATE CI half width: -0.7023843229152726

# %%
summarize_evaluation_dict(PSMLP_HDPS_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.17117097675800325
# PS_MAE 95% CI: (0.1676722678823955, 0.174669685633611)
# PS_MAE CI half width: -0.0034987088756077422
# weighted PS_MAE mean: 0.09442928284406663
# weighted PS_MAE 95% CI: (0.09182577930992056, 0.0970327863782127)
# weighted PS_MAE CI half width: -0.0026035035341460677
# ----------------------
# MAE_IPW_ATE: 1.1074371337890625
# IPW_ATE 95% CI: (-4.340451928008793, -3.4446738503565166)
# IPW_ATE CI half width: -0.4478890388261383
# ----------------------
# trimming MAE_IPW_ATE: 1.0718796253204346
# trimming IPW_ATE 95% CI: (-4.2547255327073135, -3.6015153610255792)
# trimming IPW_ATE CI half width: -0.3266050858408671
# ----------------------
# clip MAE_IPW_ATE: 1.071062684059143
# clip IPW_ATE 95% CI: (-4.260467094031357, -3.5974077701431453)
# clip IPW_ATE CI half width: -0.33152966194410594

# %%
summarize_evaluation_dict(PSLSTM_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.1122233435511589
# PS_MAE 95% CI: (0.0914499316135369, 0.1329967554887809)
# PS_MAE CI half width: -0.020773411937622
# weighted PS_MAE mean: 0.06161757707595825
# weighted PS_MAE 95% CI: (0.04801070971806574, 0.07522444443385078)
# weighted PS_MAE CI half width: -0.013606867357892516
# ----------------------
# MAE_IPW_ATE: 0.6774750351905823
# IPW_ATE 95% CI: (-6.260330782745671, -3.9529926349735924)
# IPW_ATE CI half width: -1.1536690738860393
# ----------------------
# trimming MAE_IPW_ATE: 0.6586446166038513
# trimming IPW_ATE 95% CI: (-6.214063444522086, -4.009829666212617)
# trimming IPW_ATE CI half width: -1.1021168891547344
# ----------------------
# clip MAE_IPW_ATE: 0.4960789084434509
# clip IPW_ATE 95% CI: (-5.886261683794948, -3.8871892823648446)
# clip IPW_ATE CI half width: -0.9995362007150517

# %%
summarize_evaluation_dict(PSVisitBERT_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.16580975651741028
# PS_MAE 95% CI: (0.15721473809233671, 0.17440477494248385)
# PS_MAE CI half width: -0.00859501842507357
# weighted PS_MAE mean: 0.08704897463321686
# weighted PS_MAE 95% CI: (0.08267985026414171, 0.091418099002292)
# weighted PS_MAE CI half width: -0.0043691243690751475
# ----------------------
# MAE_IPW_ATE: 0.5971795916557312
# IPW_ATE 95% CI: (-6.382897644855159, -4.283906412078167)
# IPW_ATE CI half width: -1.049495616388496
# ----------------------
# trimming MAE_IPW_ATE: 0.5747326612472534
# trimming IPW_ATE 95% CI: (-6.317728975629287, -4.312183391585834)
# trimming IPW_ATE CI half width: -1.0027727920217266
# ----------------------
# clip MAE_IPW_ATE: 0.5497550964355469
# clip IPW_ATE 95% CI: (-6.310387605202392, -4.275081437721807)
# clip IPW_ATE CI half width: -1.0176530837402922

# %%
summarize_evaluation_dict(PSCodeBERT_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.1659445583820343
# PS_MAE 95% CI: (0.15024640797595, 0.1816427087881186)
# PS_MAE CI half width: -0.0156981504060843
# weighted PS_MAE mean: 0.08774613291025161
# weighted PS_MAE 95% CI: (0.07619241409243438, 0.09929985172806885)
# weighted PS_MAE CI half width: -0.011553718817817235
# ----------------------
# MAE_IPW_ATE: 0.7823784947395325
# IPW_ATE 95% CI: (-6.185537870824042, -3.6521068916467314)
# IPW_ATE CI half width: -1.2667154895886554
# ----------------------
# trimming MAE_IPW_ATE: 0.7690051198005676
# trimming IPW_ATE 95% CI: (-6.170553756853841, -3.6632910325258647)
# trimming IPW_ATE CI half width: -1.253631362163988
# ----------------------
# clip MAE_IPW_ATE: 0.7813426852226257
# clip IPW_ATE 95% CI: (-6.178180433013467, -3.6640423908047675)
# clip IPW_ATE CI half width: -1.2570690211043498

# %%
nfold_plot_propensity_score_PSLSTM("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea_gs/", 
                     "synthea_sinusitis_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea_gs/PSLSTM/",
                                   5, 64, 64, 131, 2)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 207/207 [00:02<00:00, 93.85it/s]

# %%
nfold_plot_propensity_score_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea_gs/", 
                     "synthea_sinusitis_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea_gs/PSVisitBERT/", 
                                       5, 64, 64, 131, 2, 4, [1,2,3])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 207/207 [00:04<00:00, 49.76it/s]

# %%
nfold_plot_propensity_score_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/synthea_gs/", 
                     "synthea_sinusitis_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/synthea_gs/PSCodeBERT/", 
                                       5, 64, 64, 131, 2, 4, [1,2,3], masking_prob=None)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 207/207 [00:04<00:00, 50.95it/s]
