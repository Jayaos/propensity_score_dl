# %%
from src.PSVisitBERT import *
from src.PSCodeBERT import *
from src.SyntheticDataGeneration import *
from src.utils import *
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
nfold_average_attention_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                                   "occurrence_distance_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/occurrence_distance_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSVisitBERT/", 
                                   10, 64, 64, 104, 2, 4, [1,2,3])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:03<00:00, 33.94it/s]
# target_attention_weight_avg: 0.19977796375751494
# target_attention_weight 95% CI: (0.1635805871912287, 0.23597534032380119)
# target_attention_weight CI half width: -0.03619737656628624
# ----------------------
# rest_attention_weight_avg: 0.06171828508377075
# rest_attention_weight 95% CI: (0.05641308166765328, 0.06702348849988823)
# rest_attention_weight CI half width: -0.005305203416117475
# ----------------------
# CLS_attention_weight_avg: 0.054837885312736034
# CLS_attention_weight 95% CI: (0.04252464238701616, 0.06715112823845591)
# CLS_attention_weight CI half width: -0.012313242925719878

# %%
nfold_average_attention_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                                   "occurrence_distance_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/occurrence_distance_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSCodeBERT/", 10, 
                                   64, 64, 104, 2, 4, [1,2,3])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:04<00:00, 24.48it/s]
# target_attention_weight_avg: 0.27583984583616256
# target_attention_weight 95% CI: (0.20826900318287694, 0.34341068848944817)
# target_attention_weight CI half width: -0.06757084265328561
# ----------------------
# rest_attention_weight_avg: 0.012652109656482936
# rest_attention_weight 95% CI: (0.010825485132577946, 0.014478734180387925)
# rest_attention_weight CI half width: -0.0018266245239049895
# ----------------------
# CLS_attention_weight_avg: 0.02242036974057555
# CLS_attention_weight 95% CI: (0.01666244715591695, 0.028178292325234153)
# CLS_attention_weight CI half width: -0.0057579225846586014

# %%
load_data("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/occurrence_distance_params.pkl")
# Out:
# {'record_len_mean': 10,
#  'record_dim': 100,
#  'alpha_range': [5, 10],
#  'beta_range': [240, 260],
#  'record_len_min': 3,
#  'confounding_var_num': 1,
#  'progression_var_num': 3,
#  'p_range': [90, 100],
#  'treatment_effect': -5,
#  'outcome_bias': 10,
#  'alpha': 30,
#  'ps_noise_var': 0.01,
#  'outcome_noise_var': 0.1,
#  'num_token_reserve': 4,
#  'confounding_var': array([18]),
#  'progression_var': array([44, 16, 18])}

# %%
a,b,c = plot_attention_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                                   "occurrence_distance_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/occurrence_distance_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSVisitBERT/", 
                                   10, 64, 64, 104, 2, 4, 10, 1, [1,2,3],
                                  "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/figures/attention_map/")
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# tensor([17,  8,  8,  8, 13, 10, 17, 13, 12, 13])

# %%
a,b,c = plot_attention_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                                   "occurrence_distance_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/occurrence_distance_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSCodeBERT/", 
                                   10, 64, 64, 104, 2, 4, 10, 1, [1,2,3], None,
                                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/figures/attention_map/OD_10/")
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
