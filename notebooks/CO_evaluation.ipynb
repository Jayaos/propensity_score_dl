# %%
from src.utils import *
import matplotlib.pyplot as plt
from src.PSMLP import *
from src.PSLSTM import *
from src.PSLR import *
from src.PSCodeBERT import *
from src.PSVisitBERT import *

# %%
PSLR_evaluation_dict = nfold_evaluate_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                     "consecutive_occurrence_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSLR/", 10, 
                     100, [0.05,0.95], [0.05,0.95], HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 571.33it/s]
# IPW-ATE : 1.8199571092923483
# PS-MAE : 0.15777219831943512
# weighted PS-MAE : 0.0821119025349617
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 765.88it/s]
# IPW-ATE with trimming: 1.819957003593445
# PS-MAE with trimming: 0.1577722579240799
# evaluation starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1374.03it/s]
# IPW-ATE with clip: 1.8199571935335794
# PS-MAE with clip: 0.15777218341827393
# evaluation starts...
# ...

# %%
PSLR_HDPS_evaluation_dict = nfold_evaluate_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                     "consecutive_occurrence_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSLR_HDPS/", 10, 
                     100, [0.05,0.95], [0.05,0.95], HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:02<00:00, 505.02it/s]
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 876.33it/s]
# IPW-ATE : 5.335659372806549
# PS-MAE : 0.18213319778442383
# weighted PS-MAE : 0.10004554688930511
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 743.83it/s]
# IPW-ATE with trimming: 5.335659087498983
# PS-MAE with trimming: 0.18213333189487457
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 870.88it/s]
# ...

# %%
PSMLP_evaluation_dict = nfold_evaluate_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                     "consecutive_occurrence_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSMLP/", 10, 
                     64, 64, 101, 2, [0.05,0.95], [0.05,0.95], HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 393.19it/s]
# evaluation done...
# IPW-ATE : 1.3532303555806477
# PS-MAE : 0.16985489428043365
# weighted PS-MAE : 0.08471156656742096
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 451.43it/s]
# evaluation done...
# IPW-ATE with trimming: 1.5881157795588174
# PS-MAE with trimming: 0.16984033584594727
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 548.76it/s]
# evaluation done...
# IPW-ATE with clip: 1.3116558837890624
# PS-MAE with clip: 0.1687939316034317
# ...

# %%
PSMLP_HDPS_evaluation_dict = nfold_evaluate_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                     "consecutive_occurrence_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSMLP_HDPS/", 10, 
                     64, 64, 101, 2, [0.05,0.95], [0.05,0.95], HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:02<00:00, 592.30it/s]
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 341.00it/s]
# evaluation done...
# IPW-ATE : 6.401206277211507
# PS-MAE : 0.1843429058790207
# weighted PS-MAE : 0.10196583718061447
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 365.48it/s]
# evaluation done...
# IPW-ATE with trimming: 6.437533508936564
# PS-MAE with trimming: 0.1847938597202301
# evaluation starts...
# ...

# %%
PSLSTM_evaluation_dict = nfold_evaluate_PSLSTM("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                     "consecutive_occurrence_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSLSTM/",
                      10, 64, 64, 104, 2, [0.05,0.95], [0.05,0.95])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:01<00:00, 82.82it/s]
# evaluation done...
# IPW-ATE : 0.5824943033854166
# PS-MAE : 0.1336996853351593
# weighted PS-MAE : 0.06738732010126114
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:01<00:00, 82.97it/s]
# evaluation done...
# IPW-ATE with trimming: 0.2928631909688314
# PS-MAE with trimming: 0.1315528303384781
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:01<00:00, 85.52it/s]
# evaluation done...
# IPW-ATE with clip: 0.45011720259984334
# PS-MAE with clip: 0.1340232789516449
# ...

# %%
PSVisitBERT_evaluation_dict = nfold_evaluate_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                     "consecutive_occurrence_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSVisitBERT/", 
                               10, 64, 64, 104, 2, 4, 
                          [1,2,3], [0.05,0.95], [0.05,0.95])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 146.78it/s]
# evaluation done...
# IPW-ATE : 0.2831511783599854
# PS-MAE : 0.16108936071395874
# weighted PS-MAE : 0.0780269205570221
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 152.62it/s]
# evaluation done...
# IPW-ATE with trimming: 0.23785183270772298
# PS-MAE with trimming: 0.16141852736473083
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 155.04it/s]
# evaluation done...
# IPW-ATE with clip: 0.2687186606725057
# PS-MAE with clip: 0.16121676564216614
# ...

# %%
PSCodeBERT_evaluation_dict = nfold_evaluate_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                     "consecutive_occurrence_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSCodeBERT/", 
                               10, 64, 64, 104, 2, 4, 
                          [1,2,3], [0.05,0.95], [0.05,0.95])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:05<00:00, 21.13it/s]
# evaluation done...
# IPW-ATE : -1.7297646729151408
# PS-MAE : 0.1635364592075348
# weighted PS-MAE : 0.07472138106822968
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:05<00:00, 21.12it/s]
# evaluation done...
# IPW-ATE with trimming: -1.7297642596562703
# PS-MAE with trimming: 0.1635364443063736
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:05<00:00, 21.47it/s]
# evaluation done...
# IPW-ATE with clip: -1.729764493306478
# PS-MAE with clip: 0.16353638470172882
# ...

# %%
summarize_evaluation_dict(PSLR_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.15595636665821075
# PS_MAE 95% CI: (0.15398376226442176, 0.15792897105199974)
# PS_MAE CI half width: -0.0019726043937889903
# weighted PS_MAE mean: 0.08504070565104485
# weighted PS_MAE 95% CI: (0.0833847703956262, 0.0866966409064635)
# weighted PS_MAE CI half width: -0.0016559352554186557
# ----------------------
# MAE_IPW_ATE: 7.529298305511475
# IPW_ATE 95% CI: (1.3947563447790998, 3.6638399070265235)
# IPW_ATE CI half width: -1.1345417811237117
# ----------------------
# trimming MAE_IPW_ATE: 7.529298305511475
# trimming IPW_ATE 95% CI: (1.3947562863987655, 3.6638398466744055)
# trimming IPW_ATE CI half width: -1.13454178013782
# ----------------------
# clip MAE_IPW_ATE: 7.529298305511475
# clip IPW_ATE 95% CI: (1.3947562725845097, 3.663839809943923)
# clip IPW_ATE CI half width: -1.1345417686797066

# %%
summarize_evaluation_dict(PSLR_HDPS_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.1837392494082451
# PS_MAE 95% CI: (0.18029486257016747, 0.18718363624632273)
# PS_MAE CI half width: -0.003444386838077629
# weighted PS_MAE mean: 0.10013163238763809
# weighted PS_MAE 95% CI: (0.09750973882853675, 0.10275352594673942)
# weighted PS_MAE CI half width: -0.002621893559101335
# ----------------------
# MAE_IPW_ATE: 9.441550254821777
# IPW_ATE 95% CI: (3.6470042852684585, 5.236096720444687)
# IPW_ATE CI half width: -0.7945462175881142
# ----------------------
# trimming MAE_IPW_ATE: 9.439716339111328
# trimming IPW_ATE 95% CI: (3.6450040795723906, 5.234428886837017)
# trimming IPW_ATE CI half width: -0.794712403632313
# ----------------------
# clip MAE_IPW_ATE: 9.441553115844727
# clip IPW_ATE 95% CI: (3.6470073837551817, 5.236099257378444)
# clip IPW_ATE CI half width: -0.7945459368116312

# %%
summarize_evaluation_dict(PSMLP_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.15986039936542512
# PS_MAE 95% CI: (0.15577481368789745, 0.1639459850429528)
# PS_MAE CI half width: -0.0040855856775276755
# weighted PS_MAE mean: 0.08451082333922386
# weighted PS_MAE 95% CI: (0.0816877413599819, 0.08733390531846581)
# weighted PS_MAE CI half width: -0.0028230819792419565
# ----------------------
# MAE_IPW_ATE: 7.178597450256348
# IPW_ATE 95% CI: (1.3490945894471262, 3.0081004709649624)
# IPW_ATE CI half width: -0.8295029407589181
# ----------------------
# trimming MAE_IPW_ATE: 7.233132362365723
# trimming IPW_ATE 95% CI: (1.4040353824936465, 3.062228051030251)
# trimming IPW_ATE CI half width: -0.8290963342683022
# ----------------------
# clip MAE_IPW_ATE: 7.164371490478516
# clip IPW_ATE 95% CI: (1.2742446918168595, 3.0544983331681363)
# clip IPW_ATE CI half width: -0.8901268206756383

# %%
summarize_evaluation_dict(PSMLP_HDPS_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.18531572818756104
# PS_MAE 95% CI: (0.1802808335578556, 0.19035062281726647)
# PS_MAE CI half width: -0.005034894629705439
# weighted PS_MAE mean: 0.09727328792214393
# weighted PS_MAE 95% CI: (0.09405431869771996, 0.1004922571465679)
# weighted PS_MAE CI half width: -0.0032189692244239676
# ----------------------
# MAE_IPW_ATE: 8.531129837036133
# IPW_ATE 95% CI: (1.819488070733058, 5.242771157337519)
# IPW_ATE CI half width: -1.7116415433022307
# ----------------------
# trimming MAE_IPW_ATE: 8.524544715881348
# trimming IPW_ATE 95% CI: (1.770894773733478, 5.278195628710725)
# trimming IPW_ATE CI half width: -1.7536504274886235
# ----------------------
# clip MAE_IPW_ATE: 8.513656616210938
# clip IPW_ATE 95% CI: (1.7538333821147505, 5.273480867082891)
# clip IPW_ATE CI half width: -1.7598237424840704

# %%
summarize_evaluation_dict(PSLSTM_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.14721477925777435
# PS_MAE 95% CI: (0.1417752248856795, 0.1526543336298692)
# PS_MAE CI half width: -0.00543955437209484
# weighted PS_MAE mean: 0.07559384256601334
# weighted PS_MAE 95% CI: (0.07236392743587253, 0.07882375769615416)
# weighted PS_MAE CI half width: -0.0032299151301408147
# ----------------------
# MAE_IPW_ATE: 5.516324996948242
# IPW_ATE 95% CI: (-0.7234922657391606, 1.7561417422673284)
# IPW_ATE CI half width: -1.2398170040032446
# ----------------------
# trimming MAE_IPW_ATE: 5.559362411499023
# trimming IPW_ATE 95% CI: (-0.7450853912529324, 1.8638107335328753)
# trimming IPW_ATE CI half width: -1.3044480623929038
# ----------------------
# clip MAE_IPW_ATE: 5.736837863922119
# clip IPW_ATE 95% CI: (-0.5028777056454722, 1.976552917869797)
# clip IPW_ATE CI half width: -1.2397153117576345

# %%
summarize_evaluation_dict(PSVisitBERT_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.16161585301160813
# PS_MAE 95% CI: (0.15908514905938084, 0.16414655696383543)
# PS_MAE CI half width: -0.0025307039522272923
# weighted PS_MAE mean: 0.08339680582284928
# weighted PS_MAE 95% CI: (0.0798703869234933, 0.08692322472220526)
# weighted PS_MAE CI half width: -0.003526418899355982
# ----------------------
# MAE_IPW_ATE: 6.819024562835693
# IPW_ATE 95% CI: (0.520131421568585, 3.117917001721668)
# IPW_ATE CI half width: -1.2988927900765415
# ----------------------
# trimming MAE_IPW_ATE: 6.806454658508301
# trimming IPW_ATE 95% CI: (0.5176129682931772, 3.095296435820141)
# trimming IPW_ATE CI half width: -1.288841733763482
# ----------------------
# clip MAE_IPW_ATE: 6.8155341148376465
# clip IPW_ATE 95% CI: (0.5157414169015802, 3.1153282629944563)
# clip IPW_ATE CI half width: -1.299793423046438

# %%
summarize_evaluation_dict(PSCodeBERT_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.1588294506072998
# PS_MAE 95% CI: (0.15565786109681687, 0.16200104011778274)
# PS_MAE CI half width: -0.003171589510482936
# weighted PS_MAE mean: 0.07442528977990151
# weighted PS_MAE 95% CI: (0.07346806277813231, 0.07538251678167071)
# weighted PS_MAE CI half width: -0.0009572270017692008
# ----------------------
# MAE_IPW_ATE: 3.6376426219940186
# IPW_ATE 95% CI: (-3.4726932144319043, 0.01896119961689191)
# IPW_ATE CI half width: -1.745827207024398
# ----------------------
# trimming MAE_IPW_ATE: 3.639650821685791
# trimming IPW_ATE 95% CI: (-3.4728181246418197, 0.023102320884087257)
# trimming IPW_ATE CI half width: -1.7479602227629534
# ----------------------
# clip MAE_IPW_ATE: 3.6376380920410156
# clip IPW_ATE 95% CI: (-3.4726930440135204, 0.018951392955323554)
# clip IPW_ATE CI half width: -1.7458222184844219

# %%
nfold_plot_propensity_score_PSLSTM("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                     "consecutive_occurrence_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSLSTM/",
                                   10, 64, 64, 104, 2)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:02<00:00, 59.37it/s]

# %%
nfold_plot_propensity_score_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                     "consecutive_occurrence_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSCodeBERT/", 
                                       10, 64, 64, 104, 2, 4, [1,2,3], masking_prob=None)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:06<00:00, 18.65it/s]

# %%
nfold_plot_propensity_score_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                     "consecutive_occurrence_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSVisitBERT/",
                                   10, 64, 64, 104, 2, 4, [1,2,3])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:05<00:00, 23.94it/s]
