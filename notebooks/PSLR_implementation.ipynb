# %%
from src.PSLR import *
from src.SyntheticDataGeneration import *
from src.utils import *
import matplotlib.pyplot as plt

# %%
nfold_train_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                 "consecutive_occurrence_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSLR/", 
                 10, 100, 50, 16, 0.001, early_stop=True, HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# loading data...
# loading data done...
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 2373.28it/s]
# initial validation loss: 0.7317724573115508
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:00<00:00, 924.42it/s]
# calculating validation loss...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 2255.22it/s]
# training loss: 0.6740220838288467
# validation loss: 0.6644844065109888
# epoch 2
# ...

# %%
nfold_train_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                 "consecutive_occurrence_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSLR_HDPS/", 
                 10, 100, 50, 16, 0.001, early_stop=True, HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:01<00:00, 693.96it/s]
# loading data...
# loading data done...
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 2241.20it/s]
# initial validation loss: 0.7012919331590335
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:00<00:00, 918.06it/s]
# calculating validation loss...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 2264.38it/s]
# training loss: 0.6765560005108515
# ...

# %%
nfold_train_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                 "occurrence_count_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSLR/", 
                 10, 100, 50, 16, 0.001, early_stop=True, HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# loading data...
# loading data done...
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1061.22it/s]
# initial validation loss: 0.7082089528441429
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:01<00:00, 528.41it/s]
# calculating validation loss...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1537.56it/s]
# training loss: 0.6236276689668496
# validation loss: 0.5863790472348531
# epoch 2
# ...

# %%
nfold_train_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                 "occurrence_count_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSLR_HDPS/", 
                 10, 100, 50, 16, 0.001, early_stop=True, HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:03<00:00, 361.48it/s]
# loading data...
# loading data done...
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1334.31it/s]
# initial validation loss: 0.7003149549166362
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:01<00:00, 472.06it/s]
# calculating validation loss...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1017.95it/s]
# training loss: 0.6574361220002174
# ...

# %%
nfold_train_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                 "occurrence_distance_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSLR/", 
                 10, 100, 50, 16, 0.001, early_stop=True, HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# loading data...
# loading data done...
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 2057.70it/s]
# initial validation loss: 0.7203637619813283
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:00<00:00, 605.79it/s]
# calculating validation loss...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1939.63it/s]
# training loss: 0.7030632840593656
# validation loss: 0.6890113264322281
# epoch 2
# ...

# %%
nfold_train_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                 "occurrence_distance_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSLR_HDPS/", 
                 10, 100, 50, 16, 0.001, early_stop=True, HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:03<00:00, 397.69it/s]
# loading data...
# loading data done...
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1543.47it/s]
# initial validation loss: 0.7033064951499303
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:01<00:00, 477.04it/s]
# calculating validation loss...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1574.00it/s]
# training loss: 0.6915427987774213
# ...

# %%
nfold_train_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CoCount_10/", 
                 "cooccurrence_count_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CoCount_10/PSLR/", 
                 10, 100, 50, 16, 0.001, early_stop=True, HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# loading data...
# loading data done...
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 2121.85it/s]
# initial validation loss: 0.7294382318854332
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:00<00:00, 977.41it/s]
# calculating validation loss...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 2196.97it/s]
# training loss: 0.6740076677997907
# validation loss: 0.6483514542380969
# epoch 2
# ...

# %%
nfold_train_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CoCount_10/", 
                 "cooccurrence_count_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CoCount_10/PSLR_HDPS/", 
                 10, 100, 50, 16, 0.001, early_stop=True, HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:02<00:00, 581.34it/s]
# loading data...
# loading data done...
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 2161.91it/s]
# initial validation loss: 0.6868188495437304
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:00<00:00, 880.32it/s]
# calculating validation loss...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 2727.28it/s]
# training loss: 0.6750703782836596
# ...
