# %%
from src.PSMLP import *
from src.SyntheticDataGeneration import *
from src.utils import *
import matplotlib.pyplot as plt

# %%
nfold_train_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                 "consecutive_occurrence_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSMLP/", 
                 10, 64, 64, 101, 2, 50, 16, 0.0001, early_stop=True, HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 299.54it/s]
# initial validation loss: 0.6925595819950103
# epoch 1
#   8%|██████▍                                                                          | 48/600 [00:00<00:05, 95.64it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nfold_train_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/",
#       2                  "consecutive_occurrence_patient_record",
# ...

# %%
nfold_train_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                 "consecutive_occurrence_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSMLP_HDPS/", 
                 10, 64, 64, 101, 2, 50, 16, 0.0001, early_stop=True, HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:01<00:00, 687.90it/s]
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 527.11it/s]
# initial validation loss: 0.6921721071004867
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:03<00:00, 174.13it/s]
# calculating validation loss...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 743.79it/s]
# training loss: 0.6891723124186198
# validation loss: 0.6860526526967684
# epoch 2
# ...

# %%
nfold_train_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                 "occurrence_count_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSMLP/", 
                 10, 64, 64, 101, 2, 50, 16, 0.0001, early_stop=True, HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 675.83it/s]
# initial validation loss: 0.6922395716110865
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:02<00:00, 262.74it/s]
# calculating validation loss...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1215.01it/s]
# training loss: 0.6757829892635345
# validation loss: 0.6428790658712387
# epoch 2
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:02<00:00, 277.44it/s]
# ...

# %%
nfold_train_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                 "occurrence_count_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSMLP_HDPS/", 
                 10, 64, 64, 101, 2, 50, 16, 0.0001, early_stop=True, HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:01<00:00, 770.55it/s]
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 946.95it/s]
# initial validation loss: 0.6931066726644833
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:02<00:00, 253.26it/s]
# calculating validation loss...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1102.40it/s]
# training loss: 0.6921015705664952
# validation loss: 0.6914286216100057
# epoch 2
# ...

# %%
nfold_train_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                 "occurrence_distance_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSMLP/", 
                 10, 64, 64, 101, 2, 50, 16, 0.0001, early_stop=True, HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 623.68it/s]
# initial validation loss: 0.6924524342020353
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:03<00:00, 164.85it/s]
# calculating validation loss...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 587.92it/s]
# training loss: 0.6914575254917145
# validation loss: 0.6922156165043513
# epoch 2
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:03<00:00, 153.59it/s]
# ...

# %%
nfold_train_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                 "occurrence_distance_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSMLP_HDPS/", 
                 10, 64, 64, 101, 2, 50, 16, 0.0001, early_stop=True, HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:01<00:00, 717.20it/s]
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 574.70it/s]
# initial validation loss: 0.6929113333423932
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:02<00:00, 219.73it/s]
# calculating validation loss...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 743.05it/s]
# training loss: 0.6913588288426399
# validation loss: 0.6925114065408706
# epoch 2
# ...

# %%
nfold_train_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CoCount_10/", 
                 "cooccurrence_count_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CoCount_10/PSMLP/", 
                 10, 64, 64, 101, 2, 50, 16, 0.0001, early_stop=True, HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 670.16it/s]
# initial validation loss: 0.6917816549539566
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:02<00:00, 230.80it/s]
# calculating validation loss...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 854.51it/s]
# training loss: 0.6798191207647324
# validation loss: 0.6666166906555494
# epoch 2
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:02<00:00, 213.86it/s]
# ...

# %%
nfold_train_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CoCount_10/", 
                 "cooccurrence_count_patient_record", 
                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CoCount_10/PSMLP_HDPS/", 
                 10, 64, 64, 101, 2, 50, 16, 0.0001, early_stop=True, HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:01<00:00, 713.34it/s]
# building and initializing model...
# building and initializing model done...
# training starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 652.36it/s]
# initial validation loss: 0.694330008327961
# epoch 1
# 100%|███████████████████████████████████████████████████████████████████████████████| 600/600 [00:02<00:00, 209.22it/s]
# calculating validation loss...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 590.93it/s]
# training loss: 0.6905441007018089
# validation loss: 0.6880950515468915
# epoch 2
# ...
