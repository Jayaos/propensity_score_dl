# %%
from src.utils import *
import matplotlib.pyplot as plt
from src.PSMLP import *
from src.PSLSTM import *
from src.PSLR import *
from src.PSCodeBERT import *
from src.PSVisitBERT import *

# %%
PSLR_evaluation_dict = nfold_evaluate_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/", 
                     "occurrence_window_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OW_10/PSLR/", 10, 
                     100, [0.05,0.95], [0.05,0.95], HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1756.92it/s]
# IPW-ATE : 5.826809136072795
# PS-MAE : 0.3160508871078491
# weighted PS-MAE : 0.14375196397304535
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 950.50it/s]
# IPW-ATE with trimming: 5.826809194087982
# PS-MAE with trimming: 0.3160509169101715
# evaluation starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 2212.23it/s]
# IPW-ATE with clip: 5.826809032758077
# PS-MAE with clip: 0.3160509169101715
# evaluation starts...
# ...

# %%
PSLR_HDPS_evaluation_dict = nfold_evaluate_PSLR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/", 
                     "occurrence_window_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OW_10/PSLR_HDPS/", 10, 
                     100, [0.05,0.95], [0.05,0.95], HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:02<00:00, 424.13it/s]
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 821.28it/s]
# IPW-ATE : 6.012527287801107
# PS-MAE : 0.2842426896095276
# weighted PS-MAE : 0.13415800034999847
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 574.18it/s]
# IPW-ATE with trimming: 6.012527262369792
# PS-MAE with trimming: 0.28424251079559326
# evaluation starts...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 1038.55it/s]
# ...

# %%
PSMLP_evaluation_dict = nfold_evaluate_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/", 
                     "occurrence_window_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OW_10/PSMLP/", 10, 
                     64, 64, 101, 2, [0.05,0.95], [0.05,0.95], HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 399.74it/s]
# evaluation done...
# IPW-ATE : 5.209793664614359
# PS-MAE : 0.27946552634239197
# weighted PS-MAE : 0.12676827609539032
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 331.27it/s]
# evaluation done...
# IPW-ATE with trimming: 5.226364926088823
# PS-MAE with trimming: 0.28202295303344727
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 453.59it/s]
# evaluation done...
# IPW-ATE with clip: 5.115122098922729
# PS-MAE with clip: 0.28013846278190613
# ...

# %%
PSMLP_HDPS_evaluation_dict = nfold_evaluate_PSMLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/", 
                     "occurrence_window_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OW_10/PSMLP_HDPS/", 10, 
                     64, 64, 101, 2, [0.05,0.95], [0.05,0.95], HDPS=True)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# 100%|█████████████████████████████████████████████████████████████████████████████| 1200/1200 [00:02<00:00, 423.74it/s]
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 400.75it/s]
# evaluation done...
# IPW-ATE : 4.429644682407379
# PS-MAE : 0.27684319019317627
# weighted PS-MAE : 0.12269991636276245
# evaluation starts...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 293.47it/s]
# evaluation done...
# IPW-ATE with trimming: 4.2080118974049885
# PS-MAE with trimming: 0.27829915285110474
# evaluation starts...
# ...

# %%
PSLSTM_evaluation_dict = nfold_evaluate_PSLSTM("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/", 
                     "occurrence_window_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OW_10/PSLSTM/",
                      10, 64, 64, 104, 2, [0.05,0.95], [0.05,0.95])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:02<00:00, 50.56it/s]
# evaluation done...
# IPW-ATE : -7.560285247166951
# PS-MAE : 0.06318863481283188
# weighted PS-MAE : 0.029520733281970024
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:02<00:00, 51.23it/s]
# evaluation done...
# IPW-ATE with trimming: -7.191979188253713
# PS-MAE with trimming: 0.06783407181501389
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:02<00:00, 55.31it/s]
# evaluation done...
# IPW-ATE with clip: -6.722763738632202
# PS-MAE with clip: 0.06122265011072159
# ...

# %%
PSVisitBERT_evaluation_dict = nfold_evaluate_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/", 
                     "occurrence_window_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OW_10/PSVisitBERT/", 
                               10, 64, 64, 104, 2, 4, 
                          [1,2,3], [0.05,0.95], [0.05,0.95])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:03<00:00, 32.64it/s]
# evaluation done...
# IPW-ATE : -2.772664672533671
# PS-MAE : 0.10649546980857849
# weighted PS-MAE : 0.049445927143096924
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:03<00:00, 34.40it/s]
# evaluation done...
# IPW-ATE with trimming: -4.225175181554598
# PS-MAE with trimming: 0.11394286155700684
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:03<00:00, 34.47it/s]
# evaluation done...
# IPW-ATE with clip: -2.5363065648078917
# PS-MAE with clip: 0.10644780844449997
# ...

# %%
PSCodeBERT_evaluation_dict = nfold_evaluate_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/", 
                     "occurrence_window_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OW_10/PSCodeBERT/", 
                               10, 64, 64, 104, 2, 4, 
                          [1,2,3], [0.05,0.95], [0.05,0.95])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:06<00:00, 17.66it/s]
# evaluation done...
# IPW-ATE : -10.085636304219564
# PS-MAE : 0.15898896753787994
# weighted PS-MAE : 0.04120304435491562
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:06<00:00, 18.20it/s]
# evaluation done...
# IPW-ATE with trimming: -10.459051903544378
# PS-MAE with trimming: 0.16190655529499054
# evaluation starts...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:08<00:00, 14.79it/s]
# evaluation done...
# IPW-ATE with clip: -10.097208265463511
# PS-MAE with clip: 0.15892459452152252
# ...

# %%
summarize_evaluation_dict(PSLR_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.3139901876449585
# PS_MAE 95% CI: (0.31156564652396085, 0.31641472876595617)
# PS_MAE CI half width: -0.0024245411209976586
# weighted PS_MAE mean: 0.1478542611002922
# weighted PS_MAE 95% CI: (0.14481458801023625, 0.15089393419034816)
# weighted PS_MAE CI half width: -0.0030396730900559554
# ----------------------
# MAE_IPW_ATE: 11.655171394348145
# IPW_ATE 95% CI: (5.798576746431918, 7.511765420945553)
# IPW_ATE CI half width: -0.8565943372568174
# ----------------------
# trimming MAE_IPW_ATE: 11.83841323852539
# trimming IPW_ATE 95% CI: (6.042846733915217, 7.6339796916969735)
# trimming IPW_ATE CI half width: -0.7955664788908781
# ----------------------
# clip MAE_IPW_ATE: 11.671963691711426
# clip IPW_ATE 95% CI: (5.82582571128055, 7.518100478936787)
# clip IPW_ATE CI half width: -0.8461373838281183

# %%
summarize_evaluation_dict(PSLR_HDPS_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.2811616837978363
# PS_MAE 95% CI: (0.27806616303104637, 0.2842572045646262)
# PS_MAE CI half width: -0.0030955207667899276
# weighted PS_MAE mean: 0.12605858147144317
# weighted PS_MAE 95% CI: (0.11818616071413372, 0.1339310022287526)
# weighted PS_MAE CI half width: -0.007872420757309442
# ----------------------
# MAE_IPW_ATE: 10.028915405273438
# IPW_ATE 95% CI: (3.482621250179313, 6.575209580076831)
# IPW_ATE CI half width: -1.5462941649487592
# ----------------------
# trimming MAE_IPW_ATE: 10.028915405273438
# trimming IPW_ATE 95% CI: (3.48262115563454, 6.575209552551289)
# trimming IPW_ATE CI half width: -1.5462941984583747
# ----------------------
# clip MAE_IPW_ATE: 10.028915405273438
# clip IPW_ATE 95% CI: (3.4826211517637127, 6.575209506195272)
# clip IPW_ATE CI half width: -1.5462941772157794

# %%
summarize_evaluation_dict(PSMLP_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.2785983681678772
# PS_MAE 95% CI: (0.27730862390854566, 0.27988811242720874)
# PS_MAE CI half width: -0.0012897442593315378
# weighted PS_MAE mean: 0.12796742841601372
# weighted PS_MAE 95% CI: (0.12422298396212347, 0.13171187286990396)
# weighted PS_MAE CI half width: -0.0037444444538902444
# ----------------------
# MAE_IPW_ATE: 10.982892036437988
# IPW_ATE 95% CI: (4.968420986298692, 6.997362309650609)
# IPW_ATE CI half width: -1.0144706616759587
# ----------------------
# trimming MAE_IPW_ATE: 10.973485946655273
# trimming IPW_ATE 95% CI: (4.984249743479621, 6.962723315928326)
# trimming IPW_ATE CI half width: -0.9892367862243523
# ----------------------
# clip MAE_IPW_ATE: 10.950390815734863
# clip IPW_ATE 95% CI: (4.9560346603078465, 6.9447475282666264)
# clip IPW_ATE CI half width: -0.99435643397939

# %%
summarize_evaluation_dict(PSMLP_HDPS_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.2825279861688614
# PS_MAE 95% CI: (0.2781611042801953, 0.28689486805752745)
# PS_MAE CI half width: -0.004366881888666074
# weighted PS_MAE mean: 0.13067593574523925
# weighted PS_MAE 95% CI: (0.1250261663371591, 0.1363257051533194)
# weighted PS_MAE CI half width: -0.005649769408080152
# ----------------------
# MAE_IPW_ATE: 11.143537521362305
# IPW_ATE 95% CI: (5.011895455215985, 7.275180723096316)
# IPW_ATE CI half width: -1.1316426339401655
# ----------------------
# trimming MAE_IPW_ATE: 11.111101150512695
# trimming IPW_ATE 95% CI: (4.940978131636104, 7.281222447091807)
# trimming IPW_ATE CI half width: -1.1701221577278513
# ----------------------
# clip MAE_IPW_ATE: 11.075613975524902
# clip IPW_ATE 95% CI: (4.872294037185084, 7.278935581364264)
# clip IPW_ATE CI half width: -1.2033207720895902

# %%
summarize_evaluation_dict(PSLSTM_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.07000488415360451
# PS_MAE 95% CI: (0.06655628457427959, 0.07345348373292943)
# PS_MAE CI half width: -0.003448599579324918
# weighted PS_MAE mean: 0.033236039243638514
# weighted PS_MAE 95% CI: (0.03185066875764929, 0.03462140972962774)
# weighted PS_MAE CI half width: -0.001385370485989225
# ----------------------
# MAE_IPW_ATE: 3.3627305030822754
# IPW_ATE 95% CI: (-9.926974584333466, -5.584500169523194)
# IPW_ATE CI half width: -2.1712372074051363
# ----------------------
# trimming MAE_IPW_ATE: 2.1572656631469727
# trimming IPW_ATE 95% CI: (-8.118149215167122, -5.21415799088266)
# trimming IPW_ATE CI half width: -1.4519956121422313
# ----------------------
# clip MAE_IPW_ATE: 2.2696425914764404
# clip IPW_ATE 95% CI: (-8.27733742741485, -4.587543320062363)
# clip IPW_ATE CI half width: -1.8448970536762435

# %%
summarize_evaluation_dict(PSVisitBERT_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.11218039095401763
# PS_MAE 95% CI: (0.10697893203079166, 0.11738184987724361)
# PS_MAE CI half width: -0.005201458923225974
# weighted PS_MAE mean: 0.05658485814929008
# weighted PS_MAE 95% CI: (0.05218192182443023, 0.06098779447414993)
# weighted PS_MAE CI half width: -0.0044029363248598505
# ----------------------
# MAE_IPW_ATE: 3.3928399085998535
# IPW_ATE 95% CI: (-5.4557006971902755, -0.3083008820943922)
# IPW_ATE CI half width: -2.5736999075479416
# ----------------------
# trimming MAE_IPW_ATE: 3.503695249557495
# trimming IPW_ATE 95% CI: (-5.112325587019946, 0.10459591337368401)
# trimming IPW_ATE CI half width: -2.608460750196815
# ----------------------
# clip MAE_IPW_ATE: 3.372117280960083
# clip IPW_ATE 95% CI: (-5.184863482719813, -0.256785441471981)
# clip IPW_ATE CI half width: -2.464039020623916

# %%
summarize_evaluation_dict(PSCodeBERT_evaluation_dict, -5)
# Out:
# PS_MAE mean: 0.15309056788682937
# PS_MAE 95% CI: (0.13645058184524889, 0.16973055392840986)
# PS_MAE CI half width: -0.016639986041580485
# weighted PS_MAE mean: 0.0484501663595438
# weighted PS_MAE 95% CI: (0.04496605322903268, 0.05193427949005492)
# weighted PS_MAE CI half width: -0.0034841131305111198
# ----------------------
# MAE_IPW_ATE: 2.4047389030456543
# IPW_ATE 95% CI: (-8.64955178987887, -5.389992540400161)
# IPW_ATE CI half width: -1.6297796247393546
# ----------------------
# trimming MAE_IPW_ATE: 2.4455864429473877
# trimming IPW_ATE 95% CI: (-8.635385119364617, -5.25651214418204)
# trimming IPW_ATE CI half width: -1.6894364875912888
# ----------------------
# clip MAE_IPW_ATE: 2.391190528869629
# clip IPW_ATE 95% CI: (-8.5782312676499, -5.350766823412009)
# clip IPW_ATE CI half width: -1.6137322221189452

# %%
nfold_plot_propensity_score_LR("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                     "occurrence_distance_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSLR/", 
                               10, 100, HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|██████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 4285.70it/s]

# %%
nfold_plot_propensity_score_MLP("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                     "occurrence_distance_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSMLP/", 
                               10, 64, 64, 101, 2, HDPS=False)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|███████████████████████████████████████████████████████████████████████████████| 120/120 [00:00<00:00, 657.37it/s]

# %%
nfold_plot_propensity_score_PSLSTM("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                     "occurrence_distance_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSLSTM/",
                                   10, 64, 64, 104, 2)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:01<00:00, 76.18it/s]

# %%
nfold_plot_propensity_score_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                     "occurrence_distance_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSVisitBERT/",
                                   10, 64, 64, 104, 2, 4, [1,2,3])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:02<00:00, 49.95it/s]

# %%
nfold_plot_propensity_score_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD_10/", 
                     "occurrence_distance_patient_record",
                     "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OD_10/PSCodeBERT/", 
                                       10, 64, 64, 104, 2, 4, [1,2,3], masking_prob=None)
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:03<00:00, 38.15it/s]
