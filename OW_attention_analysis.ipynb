# %%
from src.PSVisitBERT import *
from src.PSCodeBERT import *
from src.SyntheticDataGeneration import *
from src.utils import *
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
nfold_average_attention_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/", 
                                   "occurrence_window_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/occurrence_window_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OW_10/PSVisitBERT/", 
                                   10, 64, 64, 104, 2, 4, [1,2,3])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:04<00:00, 26.42it/s]
# target_attention_weight_avg: 0.1705619141459465
# target_attention_weight 95% CI: (0.1311379819850585, 0.20998584630683453)
# target_attention_weight CI half width: -0.03942393216088802
# ----------------------
# rest_attention_weight_avg: 0.06865938119590283
# rest_attention_weight 95% CI: (0.061808512493183504, 0.07551024989862215)
# rest_attention_weight CI half width: -0.006850868702719323
# ----------------------
# CLS_attention_weight_avg: 0.06058949157595635
# CLS_attention_weight 95% CI: (0.0423126422258836, 0.0788663409260291)
# CLS_attention_weight CI half width: -0.018276849350072746

# %%
nfold_average_attention_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/", 
                                   "occurrence_window_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/occurrence_window_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OW_10/PSCodeBERT/", 10, 
                                   64, 64, 104, 2, 4, [1,2,3])
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
# ...
# 100%|████████████████████████████████████████████████████████████████████████████████| 120/120 [00:10<00:00, 11.24it/s]
# target_attention_weight_avg: 0.15619517043232917
# target_attention_weight 95% CI: (0.11932718635847804, 0.19306315450618028)
# target_attention_weight CI half width: -0.036867984073851126
# ----------------------
# rest_attention_weight_avg: 0.008774556312710046
# rest_attention_weight 95% CI: (0.006742410697261947, 0.010806701928158146)
# rest_attention_weight CI half width: -0.0020321456154480996
# ----------------------
# CLS_attention_weight_avg: 0.027844075858592988
# CLS_attention_weight 95% CI: (0.021119057850521553, 0.03456909386666442)
# CLS_attention_weight CI half width: -0.006725018008071435

# %%
load_data("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/occurrence_window_params.pkl")
# Out:
# {'record_len_mean': 10,
#  'record_dim': 100,
#  'alpha_range': [5, 10],
#  'beta_range': [240, 260],
#  'record_len_min': 5,
#  'confounding_var_num': 1,
#  'progression_var_num': 3,
#  'p_range': [1.5, 1.6],
#  'treatment_effect': -5,
#  'outcome_bias': 10,
#  'alpha': 10,
#  'ps_noise_var': 0.01,
#  'outcome_noise_var': 0.1,
#  'num_token_reserve': 4,
#  'window_size': 3,
#  'prob_reverse_progression': 0.4,
#  'confounding_var': array([52]),
#  'progression_var': array([83, 69, 52])}

# %%
a,b,c,d,e = plot_attention_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/", 
                                   "occurrence_window_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/occurrence_window_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OW_10/PSVisitBERT/", 
                                   10, 64, 64, 104, 2, 4, 10, 1, [1,2,3],
                                  "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/figures/attention_map/")
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data

# %%
a,b,c = plot_attention_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/", 
                                   "occurrence_window_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OW_10/occurrence_window_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OW_10/PSCodeBERT/", 
                                   10, 64, 64, 104, 2, 4, 10, 1, [1,2,3], None,
                                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/figures/attention_map/OW_10/")
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
