# %%
from src.PSVisitBERT import *
from src.PSCodeBERT import *
from src.SyntheticDataGeneration import *
from src.utils import *
import matplotlib.pyplot as plt
import scipy.stats as st

# %%
nfold_average_attention_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD/", 
                                   "consecutive_occurrence_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/consecutive_occurrence_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSVisitBERT/", 
                                   10, 64, 64, 104, 2, 4, [1,2,3])
# Out:
# loading 1-fold data
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 nfold_average_attention_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OD/",
#       2                                    "consecutive_occurrence_patient_record",
#       3                                    "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/consecutive_occurrence_params.pkl",
#       4                                    "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSVisitBERT/",
#       5                                    10, 64, 64, 104, 2, 4, [1,2,3])
#
# ...

# %%
nfold_average_attention_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/", 
                                   "consecutive_occurrence_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/CO_10/consecutive_occurrence_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/CO_10/PSCodeBERT/", 10, 
                                   64, 64, 104, 2, 4, [1,2,3])

# %%
load_data("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/occurrence_count_params.pkl")
# Out:
# {'record_len_mean': 10,
#  'record_dim': 100,
#  'alpha_range': [5, 10],
#  'beta_range': [240, 250],
#  'record_len_min': 3,
#  'confounding_var_num': 1,
#  'progression_var_num': 3,
#  'p_range': [50, 60],
#  'treatment_effect': -5,
#  'outcome_bias': 10,
#  'alpha': 10,
#  'ps_noise_var': 0.01,
#  'outcome_noise_var': 0.1,
#  'num_token_reserve': 4,
#  'confounding_var': array([33]),
#  'progression_var': array([66, 61, 33])}

# %%
a,b,c,d,e = plot_attention_PSVisitBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                                   "occurrence_count_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/occurrence_count_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSVisitBERT/", 
                                   10, 64, 64, 104, 2, 4, 10, 1, [1,2,3],
                                  "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/figures/attention_map/")
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data

# %%
a,b,c = plot_attention_PSCodeBERT("C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/", 
                                   "occurrence_count_patient_record", 
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/data/OC_10/occurrence_count_params.pkl",
                                   "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/OC_10/PSCodeBERT/", 
                                   10, 64, 64, 104, 2, 4, 10, 1, [1,2,3], None,
                                 "C:/Users/jayao/Desktop/python_projects/transformer_propensity/results/figures/attention_map/")
# Out:
# loading 1-fold data
# loading 2-fold data
# loading 3-fold data
# loading 4-fold data
# loading 5-fold data
# loading 6-fold data
# loading 7-fold data
# loading 8-fold data
# loading 9-fold data
# loading 10-fold data
